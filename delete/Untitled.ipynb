# %%
class c:
    lol = 0
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def __str__(self):
        return f"name:[{self.name}], age:[{self.age}]"

# %%
cc = c('shan', 19)

# %%
print(cc)
# Out:
# name:[shan], age:[19]

# %%
cc.haha = 'aa'

# %%
cc.haha
# Out:
# 'aa'

# %%
cc.lol
# Out:
# 0

# %%
cc.lol = 20

# %%
cc.lol
# Out:
# 20

# %%
c.lol
# Out:
# 0

# %%
c.lol
# Out:
# 10

# %%
cc.lol = 1

# %%
c.lol = 10

# %%
c.lol = 12

# %%
c.lol
# Out:
# 12

# %%
c.lol
# Out:
# 22

# %%
cc.lol
# Out:
# 1

# %%
cc.__class__.lol = 22
